# %%
# %matplotlib widget

import psyplot.project as psy

import numpy as np
import xarray as xr

import pkg_resources

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
# from IPython.display import display, Video

from ipympl.backend_nbagg import Canvas
# Canvas.header_visible.default_value = False

# import warnings
# warnings.filterwarnings("ignore", r"\s*The on_mappable_changed")
# warnings.filterwarnings("ignore", r"\s*The input coordinates")
# warnings.filterwarnings("ignore", r"\s*shading=")
# warnings.filterwarnings("ignore", r"\s*\[Warning by")

# # # show the figures inline in the notebook and not in a separate window
# %matplotlib inline
# # # don't close the figures after showing them, because than the update
# # # would not work
# %config InlineBackend.close_figures = False
# # # show the figures after they are drawn or updated. This is useful
# # # for the visualization in the jupyter notebook
# psy.rcParams['auto_show'] = True
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c93e2b135a6e> in <module>
#      12 # from IPython.display import display, Video
#      13
# ---> 14 from ipympl.backend_nbagg import Canvas
#      15 # Canvas.header_visible.default_value = False
#      16
#
# ModuleNotFoundError: No module named 'ipympl'

# %%
pkg_resources.get_distribution('matplotlib')
# Out:
# matplotlib 3.3.2 (/sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages)

# %%
ds = xr.open_dataset('demo.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 96, lev: 4, lon: 192, time: 5)
# Coordinates:
#   * lon      (lon) float64 0.0 1.875 3.75 5.625 7.5 ... 352.5 354.4 356.2 358.1
#   * lat      (lat) float64 88.57 86.72 84.86 83.0 ... -83.0 -84.86 -86.72 -88.57
#   * lev      (lev) float64 1e+05 8.5e+04 5e+04 2e+04
#   * time     (time) datetime64[ns] 1979-01-31T18:00:00 ... 1979-05-31T18:00:00
# Data variables:
#     t2m      (time, lev, lat, lon) float32 ...
#     u        (time, lev, lat, lon) float32 ...
#     v        (time, lev, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.6.8 (http://mpimet.mpg.de/...
#     Conventions:  CF-1.4
#     history:      Mon Aug 17 22:51:40 2015: cdo -r copy test-t2m-u-v.nc test-...
#     title:        Test file
#     CDO:          Climate Data Operators version 1.6.8rc2 (http://mpimet.mpg....

# %%
p = psy.plot.mapplot('demo.nc', name='t2m')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-bf14dd9e7792> in <module>
# ----> 1 p = psy.plot.mapplot('demo.nc', name='t2m')
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psyplot/project.py in __call__(self, *args, **kwargs)
#    1960                 [('prefer_list', self._prefer_list),
#    1961                  ('default_slice', self._default_slice)],
# -> 1962                 six.iteritems(self._default_dims), six.iteritems(kwargs))))
#    1963
#    1964     def __getattr__(self, attr):
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psyplot/project.py in _add_data(self, *args, **kwargs)
#    1745         # method but is reimplemented by subclasses as the
#    1746         # :class:`DatasetPlotter` or the :class:`DataArrayPlotter`
# -> 1747         return self.project._add_data(*args, **kwargs)
#    1748
#    1749     @classmethod
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psyplot/project.py in wrapper(self, *args, **kwargs)
#     154         if not self.is_main:
#     155             return getattr(self.main, func.__name__)(*args, **kwargs)
# --> 156         return func(self, *args, **kwargs)
#     157     return wrapper
#     158
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psyplot/project.py in _add_data(self, plotter_cls, filename_or_obj, fmt, make_plot, draw, mf_mode, ax, engine, delete, share, clear, enable_post, concat_dim, load, *args, **kwargs)
#     777             plotter_cls(arr, make_plot=(not bool(share) and make_plot),
#     778                         draw=False, ax=next(axes), clear=clear,
# --> 779                         project=self, enable_post=enable_post, **fmt)
#     780         if share:
#     781             if share is True:
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psyplot/plotter.py in __init__(self, data, ax, auto_update, project, draw, make_plot, clear, enable_post, **kwargs)
#    1200             self[key] = value
#    1201         self.initialize_plot(data, ax=ax, draw=draw, clear=clear,
# -> 1202                              make_plot=make_plot)
#    1203
#    1204     def _try2set(self, fmto, *args, **kwargs):
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psyplot/plotter.py in initialize_plot(self, data, ax, make_plot, clear, draw, remove, priority)
#    1358             if priority is None or fmto_priority == priority:
#    1359                 self._plot_by_priority(fmto_priority, grouper,
# -> 1360                                        initializing=True)
#    1361         self._release_all(True)  # finish the update
#    1362         self.cleared = False
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psyplot/plotter.py in _plot_by_priority(self, priority, fmtos, initializing)
#    1562             for fmto in fmtos:
#    1563                 update(fmto)
# -> 1564             self._make_plot()
#    1565
#    1566         self._initializing = False
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psyplot/plotter.py in _make_plot(self)
#    2405         for fmto in plot_fmtos:
#    2406             self.logger.debug("Making plot with %s formatoption", fmto.key)
# -> 2407             fmto.make_plot()
#    2408
#    2409     @classmethod
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psy_simple/plotters.py in make_plot(self)
#    3283                      "in the future. Use 'poly' instead!",
#    3284                      DeprecationWarning)
# -> 3285             self._plot_funcs[self.value]()
#    3286             if self._orig_format_coord is None:
#    3287                 self._orig_format_coord = self.ax.format_coord
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/psy_simple/plotters.py in _pcolormesh(self)
#    3307             self._plot = self.ax.pcolormesh(
#    3308                 x, y, arr, norm=self.bounds.norm,
# -> 3309                 cmap=cmap, rasterized=True, **self._kwargs)
#    3310
#    3311     def _get_xy_pcolormesh(self):
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py in pcolormesh(self, *args, **kwargs)
#    1457                              ' consider using PlateCarree/RotatedPole.')
#    1458         kwargs.setdefault('transform', t)
# -> 1459         result = self._pcolormesh_patched(*args, **kwargs)
#    1460         self.autoscale_view()
#    1461         return result
#
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py in _pcolormesh_patched(self, *args, **kwargs)
#    1489         allmatch = (shading == 'gouraud')
#    1490
# -> 1491         X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
#    1492         Ny, Nx = X.shape
#    1493
#
# TypeError: _pcolorargs() got an unexpected keyword argument 'allmatch'
# /sw/spack-rhel6/anaconda3-2020.02-dqbodz/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:388: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   inframe=inframe)
